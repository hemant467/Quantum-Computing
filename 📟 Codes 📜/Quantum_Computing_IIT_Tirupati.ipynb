# %% [markdown]
# <div align="center">
#
# # IIT Tirupati
# ## Quantum Computing
# ### By Dr. J. Senthil Kumar
#
# </div>

# %%
# !pip install qiskit qiskit-aer matplotlib pylatexent --quiet
# Create a circuit with 1 qubit and 1 classical bit
from qiskit import QuantumCircuit
qc = QuantumCircuit(1,1)

# Apply a Madamrd gate to create a superposition: (|0> + |1>))/sqrt(2) - 50%
qc.h(0)

#Measure the qubit
qc.measure(0, 0)

#Draw the circuit
print(qc.draw())
# Out:
# ERROR: Could not find a version that satisfies the requirement pylatexent (from versions: none)
# ERROR: No matching distribution found for pylatexent
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-359/4282581721.py in <cell line: 0>()
#       1 get_ipython().system('pip install qiskit qiskit-aer matplotlib pylatexent --quiet')
#       2 # Create a circuit with 1 qubit and 1 classical bit
# ----> 3 from qiskit import QuantumCircuit
#       4 qc = QuantumCircuit(1,1)
#       5
#
# ModuleNotFoundError: No module named 'qiskit'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install qiskit matplotlib --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 82.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 62.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 3.5 MB/s eta 0:00:00

# %%
# Create a circuit with 1 qubit and 1 classical bit
from qiskit import QuantumCircuit
qc = QuantumCircuit(1,1)

# Apply a Madamrd gate to create a superposition: (|0> + |1>))/sqrt(2) - 50%
qc.h(0)

#Measure the qubit
qc.measure(0, 0)

#Draw the circuit
print(qc.draw())
# Out:
#      ┌───┐┌─┐
#   q: ┤ H ├┤M├
#      └───┘└╥┘
# c: 1/══════╩═
#            0

# %%
qc.x(0)

# %%
print(qc.draw())
# Out:
#      ┌───┐┌─┐┌───┐
#   q: ┤ H ├┤M├┤ X ├
#      └───┘└╥┘└───┘
# c: 1/══════╩══════
#            0

# %%
qc.x(0)
print(qc.draw())
# Out:
#      ┌───┐┌─┐┌───┐┌───┐
#   q: ┤ H ├┤M├┤ X ├┤ X ├
#      └───┘└╥┘└───┘└───┘
# c: 1/══════╩═══════════
#            0

# %%
from qiskit import QuantumCircuit
qc = QuantumCircuit(2,2)

# Apply the Hadamard gate to create a superposition:
qc.h(0)
qc.x(0)
qc.x(1)

# Measure the qubit
qc.measure(0,0)

qc.measure(1,0)

# Draw the circuit
qc.draw()
# Out:
#      ┌───┐┌───┐┌─┐
# q_0: ┤ H ├┤ X ├┤M├───
#      ├───┤└───┘└╥┘┌─┐
# q_1: ┤ X ├──────╫─┤M├
#      └───┘      ║ └╥┘
# c: 2/═══════════╩══╩═
#                 0  0

# %%
from qiskit import QuantumCircuit

qc = QuantumCircuit(2, 2)

qc.h(0)
qc.x(0)
qc.x(1)

qc.measure(0, 0)
qc.measure(1, 1)

qc.draw()
# Out:
#      ┌───┐┌───┐┌─┐
# q_0: ┤ H ├┤ X ├┤M├
#      ├───┤└┬─┬┘└╥┘
# q_1: ┤ X ├─┤M├──╫─
#      └───┘ └╥┘  ║
# c: 2/═══════╩═══╩═
#             1   0

# %%
qc =QuantumCircuit(2,2)  # (2,2) = (q0 , q1 ) = q-bits ; q-bit 1 | q-bit 2
qc.h(0)   # create superposition
qc.cx(0,1) # entangle qubits
qc.measure([0,1],[0,1])
qc.draw()
# Out:
#      ┌───┐     ┌─┐
# q_0: ┤ H ├──■──┤M├───
#      └───┘┌─┴─┐└╥┘┌─┐
# q_1: ─────┤ X ├─╫─┤M├
#           └───┘ ║ └╥┘
# c: 2/═══════════╩══╩═
#                 0  1

# %%
qc =QuantumCircuit(2,2)  # (2,2) = (q0 , q1 ) = q-bits ; q-bit 1 | q-bit 2
qc.h(0)   # create superposition
qc.cx(0,1) # entangle qubits
qc.measure([0,1],[1,1])
qc.draw()
# Out:
#      ┌───┐     ┌─┐
# q_0: ┤ H ├──■──┤M├───
#      └───┘┌─┴─┐└╥┘┌─┐
# q_1: ─────┤ X ├─╫─┤M├
#           └───┘ ║ └╥┘
# c: 2/═══════════╩══╩═
#                 1  1

# %% [markdown]
# ## Deutsch Algorithm Function

# %%
from qiskit import QuantumCircuit
from qiskt.quantum_info import Statevector

# Deutsch Algorithm Function

def deutsch_algorithm(oracle_fn):
    qc = QuantumCircuit(2,1) # 2qubits, 1 classical bit

    # Step 1: Prepare |0>|1>
